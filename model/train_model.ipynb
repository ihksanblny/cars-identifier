# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Tentukan jalur dataset
train_dir = "../Cars_Dataset/train"
test_dir = "../Cars_Dataset/test"

# Parameter dasar
IMG_SIZE = (224, 224) # Ukuran standar untuk model AI
BATCH_SIZE = 32

# Memuat data training
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical' # Karena kita punya 7 merek (multi-class)
)

# Memuat data testing (untuk validasi)
val_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

# Dapatkan nama-nama kelas (Audi, Swift, dll)
class_names = train_ds.class_names
print("Merek mobil yang terdeteksi:", class_names)
# Out:
# Found 3352 files belonging to 7 classes.
# Found 813 files belonging to 7 classes.
# Merek mobil yang terdeteksi: ['Audi', 'Hyundai Creta', 'Mahindra Scorpio', 'Rolls Royce', 'Swift', 'Tata Safari', 'Toyota Innova']

# %%
# 3. DATA AUGMENTATION (Agar AI tidak gampang menghafal/overfit)
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# 4. DOWNLOAD BRAIN (MobileNetV2)
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False # Kunci otak aslinya dulu

# 5. RAKIT MODEL (Versi Upgrade)
model = models.Sequential([
    layers.Input(shape=(224, 224, 3)),
    data_augmentation,           # Tambahkan variasi gambar otomatis
    layers.Rescaling(1./127.5, offset=-1), # Ubah pixel 0-255 jadi -1 sampai 1 (PENTING!)
    base_model,                  # Otak utama
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),         # Mencegah hafalan (overfitting)
    layers.Dense(len(class_names), activation='softmax')
])

# 6. COMPILE & TRAIN
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
print("Memulai Training Versi 2.0 (High Accuracy)...")
EPOCHS = 20 # Kita naikkan jadi 20 biar hasilnya lebih tajam
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS
)
# 7. SIMPAN HASILNYA
model.save("car_identity_model_v2.keras") # Format .keras lebih disarankan sekarang
print("Model V2 tersimpan! Siap untuk dites.")
# Out:
# Memulai Training Versi 2.0 (High Accuracy)...
# Epoch 1/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 50s 417ms/step - accuracy: 0.3604 - loss: 1.7479 - val_accuracy: 0.5560 - val_loss: 1.3714
# Epoch 2/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 386ms/step - accuracy: 0.5337 - loss: 1.3496 - val_accuracy: 0.6507 - val_loss: 1.0732
# Epoch 3/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 387ms/step - accuracy: 0.6113 - loss: 1.1566 - val_accuracy: 0.6888 - val_loss: 0.9113
# Epoch 4/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 44s 417ms/step - accuracy: 0.6483 - loss: 1.0385 - val_accuracy: 0.7331 - val_loss: 0.7946
# Epoch 5/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 390ms/step - accuracy: 0.7005 - loss: 0.9105 - val_accuracy: 0.7724 - val_loss: 0.7121
# Epoch 6/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 46s 437ms/step - accuracy: 0.7202 - loss: 0.8335 - val_accuracy: 0.7970 - val_loss: 0.6489
# Epoch 7/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 48s 452ms/step - accuracy: 0.7431 - loss: 0.7904 - val_accuracy: 0.8044 - val_loss: 0.6141
# Epoch 8/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 42s 396ms/step - accuracy: 0.7458 - loss: 0.7410 - val_accuracy: 0.8044 - val_loss: 0.5948
# Epoch 9/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 392ms/step - accuracy: 0.7563 - loss: 0.7120 - val_accuracy: 0.8106 - val_loss: 0.5653
# Epoch 10/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 42s 403ms/step - accuracy: 0.7700 - loss: 0.6860 - val_accuracy: 0.8315 - val_loss: 0.5390
# Epoch 11/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 48s 459ms/step - accuracy: 0.7828 - loss: 0.6584 - val_accuracy: 0.8118 - val_loss: 0.5262
# Epoch 12/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 379ms/step - accuracy: 0.7903 - loss: 0.6338 - val_accuracy: 0.8389 - val_loss: 0.5014
# Epoch 13/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 379ms/step - accuracy: 0.7950 - loss: 0.6184 - val_accuracy: 0.8426 - val_loss: 0.4834
# Epoch 14/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 379ms/step - accuracy: 0.7965 - loss: 0.6002 - val_accuracy: 0.8499 - val_loss: 0.4756
# Epoch 15/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 391ms/step - accuracy: 0.8162 - loss: 0.5701 - val_accuracy: 0.8512 - val_loss: 0.4667
# Epoch 16/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 382ms/step - accuracy: 0.8150 - loss: 0.5595 - val_accuracy: 0.8659 - val_loss: 0.4479
# Epoch 17/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 388ms/step - accuracy: 0.8112 - loss: 0.5558 - val_accuracy: 0.8672 - val_loss: 0.4460
# Epoch 18/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 410ms/step - accuracy: 0.8228 - loss: 0.5324 - val_accuracy: 0.8708 - val_loss: 0.4329
# Epoch 19/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 388ms/step - accuracy: 0.8153 - loss: 0.5431 - val_accuracy: 0.8684 - val_loss: 0.4317
# Epoch 20/20
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 393ms/step - accuracy: 0.8353 - loss: 0.5031 - val_accuracy: 0.8672 - val_loss: 0.4203
# Model V2 tersimpan! Siap untuk dites.

# %%
# 4. Proses Training
print("Memulai proses training...")
EPOCHS = 10 # Kita coba 10 putaran dulu

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS
)

# 5. Simpan Model
# Setelah capek belajar, modelnya harus disimpan agar bisa dipakai nanti
model.save("car_identity_model.h5")
print("Model berhasil disimpan dengan nama: car_identity_model.h5")
# Out:
# Memulai proses training...
# Epoch 1/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 47s 393ms/step - accuracy: 0.3890 - loss: 1.6765 - val_accuracy: 0.4822 - val_loss: 1.4249
# Epoch 2/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - accuracy: 0.5107 - loss: 1.3766 - val_accuracy: 0.5351 - val_loss: 1.2905
# Epoch 3/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 36s 339ms/step - accuracy: 0.5677 - loss: 1.2128 - val_accuracy: 0.5437 - val_loss: 1.2452
# Epoch 4/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - accuracy: 0.5999 - loss: 1.1148 - val_accuracy: 0.5781 - val_loss: 1.1374
# Epoch 5/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 36s 345ms/step - accuracy: 0.6351 - loss: 1.0355 - val_accuracy: 0.5892 - val_loss: 1.1363
# Epoch 6/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 36s 340ms/step - accuracy: 0.6626 - loss: 0.9625 - val_accuracy: 0.6002 - val_loss: 1.1354
# Epoch 7/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 36s 348ms/step - accuracy: 0.6936 - loss: 0.8959 - val_accuracy: 0.6015 - val_loss: 1.1391
# Epoch 8/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 36s 343ms/step - accuracy: 0.7047 - loss: 0.8514 - val_accuracy: 0.6347 - val_loss: 1.0126
# Epoch 9/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 37s 348ms/step - accuracy: 0.7273 - loss: 0.7862 - val_accuracy: 0.6298 - val_loss: 1.0249
# Epoch 10/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 36s 340ms/step - accuracy: 0.7443 - loss: 0.7289 - val_accuracy: 0.5892 - val_loss: 1.1488
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model berhasil disimpan dengan nama: car_identity_model.h5
